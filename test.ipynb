# %%
from cleaner import Cleaner
from safety_checker import SafetyChecker
from main import VoiceAgentBrain


# sample messy transcript
# not sure how to handle 'clinician' response, im assuming transcript cleaning/agent generation are confounded for simplicity
# as such we're safety checking the clinician's 'query' as well
transcript = [
    ("Clinician", "How long has this been going on?"),
    ("Patient", "It started like, uh, last Tuesday? No, wait, two Tuesdays ago."),
    ("Patient", "I've been taking... [pause]... um, propanol? No, pro-pran-o-lol for the shakes."),
    ("Patient", "But my heart feels kinda... fluttery? Is that dangerous? Should I stop taking it?")
]

agent = VoiceAgentBrain()


for speaker, line in transcript:
    print(f"Raw ({speaker}): {line}\n")

    output = agent.process(line)

    # cleaned text
    print(f"Cleaned ({speaker}): {output['cleaned_text']}\n")

    # metadata from cleaner
    metadata = agent.cleaner.clean(line)['metadata']
    print(f"Corrections detected: {metadata['corrections']}")
    print(f"Disfluencies removed: {metadata['disfluencies_removed']}")
    print(f"Noise removed: {metadata['noise_removed']}\n")

    # safety check
    print(f"Safety check: {output['safety']}\n")

    # conversation state
    print(f"Conversation state: {output['state']}")
    print(f"Agent should respond? {output['should_respond']}")
    print("-" * 80)

# reset state at end
agent.reset_state()
# Out:
# Raw (Clinician): How long has this been going on?
#
# Cleaned (Clinician): How long has this been going on?
#
# Corrections detected: []
# Disfluencies removed: []
# Noise removed: False
#
# Safety check: {'risk_level': 'low', 'is_safe': True, 'message': None}
#
# Conversation state: {'symptoms': [], 'medications': [], 'body parts': [], 'turn_count': 1}
# Agent should respond? True
# --------------------------------------------------------------------------------
# Raw (Patient): It started like, uh, last Tuesday? No, wait, two Tuesdays ago.
#
# Cleaned (Patient): It started two Tuesdays ago.
#
# Corrections detected: [('last Tuesday', 'two Tuesdays ago'), ('last Tuesday', 'two Tuesdays ago')]
# Disfluencies removed: ['uh', 'like']
# Noise removed: False
#
# Safety check: {'risk_level': 'low', 'is_safe': True, 'message': None}
#
# Conversation state: {'symptoms': [], 'medications': [], 'body parts': [], 'turn_count': 2}
# Agent should respond? True
# --------------------------------------------------------------------------------
# Raw (Patient): I've been taking... [pause]... um, propanol? No, pro-pran-o-lol for the shakes.
#
# Cleaned (Patient): I've been taking propanol? No, propranolol for the shakes.
#
# Corrections detected: []
# Disfluencies removed: ['um']
# Noise removed: True
#
# Safety check: {'risk_level': 'low', 'is_safe': True, 'message': None}
#
# Conversation state: {'symptoms': [], 'medications': ['propranolol', 'propanol'], 'body parts': [], 'turn_count': 3}
# Agent should respond? True
# --------------------------------------------------------------------------------
# Raw (Patient): But my heart feels kinda... fluttery? Is that dangerous? Should I stop taking it?
#
# Cleaned (Patient): But my heart feels fluttery? Is that dangerous? Should I stop taking it?
#
# Corrections detected: []
# Disfluencies removed: ['kinda']
# Noise removed: False
#
# Safety check: {'risk_level': 'high', 'is_safe': False, 'message': 'I cannot provide medical advice. Please contact your GP immediately.'}
#
# Conversation state: {'symptoms': ['fluttery'], 'medications': ['propranolol', 'propanol'], 'body parts': ['heart'], 'turn_count': 4}
# Agent should respond? False
# --------------------------------------------------------------------------------
